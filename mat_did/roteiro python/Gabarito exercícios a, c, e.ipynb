# %% [markdown]
# # Gabarito dos Exercícios a, c, e

# %% [markdown]
# ## 1)Use dos conhecimentos adiquiridos para:
# a) Crie variáveis e atribua valores para nome, idade(anos), altura(cm) e cidade de moradia de três pessoas e imprima as mesmas.
#
# b) Escreva agora as alturas do item a) em metros usando `float` e a mostre com duas casas após a virgula e imprima.
#
# c) Crie uma fila com as alturas das pessoas do item b), adicione mais dois valores quaisquer e imprima.
#
# d) Pegue o primeiro elemento da lista e avalie se ele é maior que 1.60, se for imprima o valor, se não imprima a mensagem "altura abaixo do esperado!".
#
# e) Crie um programa para atribuir as quatro variaveis do item a) usando `input` para três pessoas e imprima as mesmas.

# %% [markdown]
# ### Resolução a)

# %%
usuário1 = ["Luis", 23, 176, "goiania"]
usuário2 = ["Felipe", 16, 166, "aparecida de goiania"]
usuário3 = ["Marcus", 32, 177, "silvania"]
print(usuário1)
print(usuário2)
print(usuário3)
# Out:
# ['Luis', 23, 176, 'goiania']
# ['Felipe', 16, 166, 'aparecida de goiania']
# ['Marcus', 32, 177, 'silvania']

# %% [markdown]
# ### Resolução c)

# %%
alturas = [usuário1[2], usuário2[2], usuário3[2]]
alturas.append(1.80)
alturas.append(1.90)
print(alturas)
# Out:
# [176, 166, 177, 1.8, 1.9]

# %% [markdown]
# ### Resolução e)

# %%
usuário4 = [0,0,0,0]
usuário4[0] = input("Qual o seu nome? ")
usuário4[1] = input("Qual o sua idade? ")
usuário4[2] = input("Qual o sua altura? ")
usuário4[3] = input("Qual o sua cidade de moradia? ")

usuário5 = [0,0,0,0]
usuário5[0] = input("Qual o seu nome? ")
usuário5[1] = input("Qual o sua idade? ")
usuário5[2] = input("Qual o sua altura? ")
usuário5[3] = input("Qual o sua cidade de moradia? ")

usuário6 = [0,0,0,0]
usuário6[0] = input("Qual o seu nome? ")
usuário6[1] = input("Qual o sua idade? ")
usuário6[2] = input("Qual o sua altura? ")
usuário6[3] = input("Qual o sua cidade de moradia? ")
print(usuário4)
print(usuário5)
print(usuário6)
# Out:
# ['', '', '', '']
# ['', '', '', '']
# ['', '', '', '']
